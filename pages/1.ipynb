# %%
import streamlit as st
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
plt.rcParams["font.family"] = "Meiryo"

st.title("折れ線グラフの作成")
st.subheader("subtitle")
st.text("text")

"""
comment
```python
# comment
import pandas as pd
```
"""

df =  pd.read_csv("data/2022年8月気温.csv", encoding="utf-8-sig")
df = df.set_index(pd.to_datetime(df["年月"], format="%Y/%m/%d")).drop("年月",axis=1)
df.head()
# Out:
#               札幌    東京    広島    那覇
# 年月
# 2022-08-01  22.8  30.6  30.3  27.0
# 2022-08-02  22.9  31.6  30.5  29.0
# 2022-08-03  23.3  31.5  30.8  28.6
# 2022-08-04  23.1  24.6  30.8  29.5
# 2022-08-05  21.7  23.8  27.5  29.6

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)
ax1.plot(df["札幌"])
ax2.plot(df["東京"])
ax3.plot(df["広島"])
ax4.plot(df["那覇"])
st.pyplot(fig)
